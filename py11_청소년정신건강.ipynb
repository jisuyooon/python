# %%
# !dir

# %%
import pandas as pd
file_path = "./ref/청소년정신건강_20250304.csv"
ori = pd.read_csv(file_path)
ori
# Out:
#      시점 스트레스 인지율 스트레스 인지율.1 스트레스 인지율.2 우울감 경험률 우울감 경험률.1 우울감 경험률.2 자살 생각률  \
# 0    시점       전체        남학생        여학생      전체       남학생       여학생     전체
# 1  2024     45.3       39.6       51.3    28.2      23.9      32.6   14.2
#
#   자살 생각률.1 자살 생각률.2
# 0      남학생      여학생
# 1     11.1     17.4

# %%
import pandas as pd
file_path = "./ref/청소년정신건강_2023.csv"
ori2 = pd.read_csv(file_path)
ori2
# Out:
#      시점 스트레스 인지율 스트레스 인지율.1 스트레스 인지율.2 우울감 경험률 우울감 경험률.1 우울감 경험률.2 자살 생각률  \
# 0    시점       전체        남학생        여학생      전체       남학생       여학생     전체
# 1  2023     39.6       33.4       46.2    27.5      23.3      32.0   14.5
#
#   자살 생각률.1 자살 생각률.2
# 0      남학생      여학생
# 1     10.5     18.9

# %%
# 컬럼명 지정
new_name = ['시점','스트레스','스트레스남학생','스트레스여학생','우울감경험율','우울남학생', '우울여학생','자살생각율','자살남학생','자살여학생']
ori.columns= new_name
ori
# Out:
#      시점  스트레스 스트레스남학생 스트레스여학생 우울감경험율 우울남학생 우울여학생 자살생각율 자살남학생 자살여학생
# 0    시점    전체     남학생     여학생     전체   남학생   여학생    전체   남학생   여학생
# 1  2024  45.3    39.6    51.3   28.2  23.9  32.6  14.2  11.1  17.4

# %%
new_name = ['시점','스트레스','스트레스남학생','스트레스여학생','우울감경험율','우울남학생', '우울여학생','자살생각율','자살남학생','자살여학생']
ori2.columns= new_name
ori2
# Out:
#      시점  스트레스 스트레스남학생 스트레스여학생 우울감경험율 우울남학생 우울여학생 자살생각율 자살남학생 자살여학생
# 0    시점    전체     남학생     여학생     전체   남학생   여학생    전체   남학생   여학생
# 1  2023  39.6    33.4    46.2   27.5  23.3  32.0  14.5  10.5  18.9

# %%
# 시점을 없애고 , 0번 행도 없앰.
ori= ori.loc[1:,'스트레스':]
ori
# Out:
#    스트레스 스트레스남학생 스트레스여학생 우울감경험율 우울남학생 우울여학생 자살생각율 자살남학생 자살여학생
# 1  45.3    39.6    51.3   28.2  23.9  32.6  14.2  11.1  17.4

# %%
ori2= ori2.loc[1:,'스트레스':]
ori2
# Out:
#    스트레스 스트레스남학생 스트레스여학생 우울감경험율 우울남학생 우울여학생 자살생각율 자살남학생 자살여학생
# 1  39.6    33.4    46.2   27.5  23.3  32.0  14.5  10.5  18.9

# %%
ori.loc[2] = 100 - ori.loc[1,'스트레스':].astype(float)
ori['응답'] = ['그렇다','아니다']
ori
# Out:
#    스트레스 스트레스남학생 스트레스여학생 우울감경험율 우울남학생 우울여학생 자살생각율 자살남학생 자살여학생   응답
# 1  45.3    39.6    51.3   28.2  23.9  32.6  14.2  11.1  17.4  그렇다
# 2  54.7    60.4    48.7   71.8  76.1  67.4  85.8  88.9  82.6  아니다

# %%
ori2.loc[2] = 100 - ori2.loc[1,'스트레스':].astype(float)
ori2['응답'] = ['그렇다','아니다']
ori2
# Out:
#    스트레스 스트레스남학생 스트레스여학생 우울감경험율 우울남학생 우울여학생 자살생각율 자살남학생 자살여학생   응답
# 1  39.6    33.4    46.2   27.5  23.3  32.0  14.5  10.5  18.9  그렇다
# 2  60.4    66.6    53.8   72.5  76.7  68.0  85.5  89.5  81.1  아니다

# %%
ori = ori.set_index('응답')
ori
# Out:
#      스트레스 스트레스남학생 스트레스여학생 우울감경험율 우울남학생 우울여학생 자살생각율 자살남학생 자살여학생
# 응답
# 그렇다  45.3    39.6    51.3   28.2  23.9  32.6  14.2  11.1  17.4
# 아니다  54.7    60.4    48.7   71.8  76.1  67.4  85.8  88.9  82.6

# %%
ori2 = ori2.set_index('응답')
ori2
# Out:
#      스트레스 스트레스남학생 스트레스여학생 우울감경험율 우울남학생 우울여학생 자살생각율 자살남학생 자살여학생
# 응답
# 그렇다  39.6    33.4    46.2   27.5  23.3  32.0  14.5  10.5  18.9
# 아니다  60.4    66.6    53.8   72.5  76.7  68.0  85.5  89.5  81.1

# %%
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import rc
import matplotlib.font_manager as fm
fontlist = fm.findSystemFonts(fontpaths=None, fontext='ttf')
fontlist
# Out:
# ['C:\\Windows\\Fonts\\HANBatangExt.ttf',
#  'C:\\Windows\\Fonts\\LTYPEB.TTF',
#  'C:\\Windows\\Fonts\\ARIALNI.TTF',
#  'C:\\Windows\\Fonts\\seguihis.ttf',
#  'C:\\Windows\\Fonts\\corbelli.ttf',
#  'C:\\Windows\\Fonts\\courbd.ttf',
#  'C:\\Windows\\Fonts\\FRAHV.TTF',
#  'C:\\Windows\\Fonts\\ntailub.ttf',
#  'C:\\Windows\\Fonts\\H2GPRM.TTF',
#  'C:\\Windows\\Fonts\\CALIFB.TTF',
#  'C:\\Windows\\Fonts\\FTLTLT.TTF',
#  'C:\\Windows\\Fonts\\verdanai.ttf',
#  'C:\\Windows\\Fonts\\H2HDRM.TTF',
#  'C:\\Windows\\Fonts\\GILI____.TTF',
#  'C:\\Windows\\Fonts\\RAVIE.TTF',
#  'C:\\Windows\\Fonts\\HANBatangB.ttf',
#  'C:\\Windows\\Fonts\\BOOKOS.TTF',
#  'C:\\Users\\Admin\\AppData\\Local\\Microsoft\\Windows\\Fonts\\D2CodingBold-Ver1.3.2-20180524-ligature.ttf',
#  'C:\\Windows\\Fonts\\ITCEDSCR.TTF',
#  'C:\\Windows\\Fonts\\ROCK.TTF',
#  'C:\\Windows\\Fonts\\framdit.ttf',
#  'C:\\Windows\\Fonts\\HTOWERT.TTF',
#  'C:\\Windows\\Fonts\\mingliub.ttc',
#  'C:\\Windows\\Fonts\\constani.ttf',
# ...

# %%
# 윈도우용 폰트 경로 설정
path = "C:\\Windows\\Fonts\\NanumGothic.ttf"
font_name = fm.FontProperties(fname=path).get_name()
rc('font',family=font_name)
plt.text(0.2,0.4,'한글',size=100)
# Out:
# Text(0.2, 0.4, '한글')

# %%
ori['스트레스'].astype(float).plot.pie(explode = [0,0.02])
# Out:
# <Axes: ylabel='스트레스'>

# %%
fig, ax = plt.subplots(2,3,figsize=(10,8))

ori['스트레스'].astype(float).plot.pie(explode = [0,0.08], ax = ax[1][0], autopct = "%.1f%%")
ax[1][0].set_title('스트레스를 받은적 있다.')
ax[1][0].set_ylabel('')

ori2['스트레스'].astype(float).plot.pie(explode = [0,0.08], ax = ax[0][0], autopct = "%.1f%%")
ax[0][0].set_title('스트레스를 받은적 있다.')
ax[0][0].set_ylabel('')

ori['우울감경험율'].astype(float).plot.pie(explode = [0,0.08], ax = ax[1][1], autopct = "%.1f%%")
ax[1][1].set_title('우울을 경험한적 있다.')
ax[1][1].set_ylabel('')

ori2['우울감경험율'].astype(float).plot.pie(explode = [0,0.08], ax = ax[0][1], autopct = "%.1f%%")
ax[0][1].set_title('우울을 경험한적 있다.')
ax[0][1].set_ylabel('')

ori['자살생각율'].astype(float).plot.pie(explode = [0,0.08], ax = ax[1][2], autopct = "%.1f%%")
ax[1][2].set_title('자살을 고민한적 있다.')
ax[1][2].set_ylabel('')

ori2['자살생각율'].astype(float).plot.pie(explode = [0,0.08], ax = ax[0][2], autopct = "%.1f%%")
ax[0][2].set_title('자살을 고민한적 있다.')
ax[0][2].set_ylabel('')

plt.suptitle('2023 ~ 2024년 청소년 정신건강관련 통계',fontsize=16)
plt.show()
